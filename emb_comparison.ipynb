# %%
# ------------------------
# IMPORTS
# ------------------------

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import torch

from scipy.spatial.distance import pdist, squareform
from sklearn.decomposition import PCA

from src.embedding.netlsd import NetLSD
from src.embedding.feather import FEATHERG
from src.embedding.gnn_model import GNN
from src.utils import read_config

# %%
# ============================================================
# Graph Embedding Comparison Notebook
# NetLSD vs FEATHERG vs GNN
# ============================================================

# ------------------------
# GLOBAL CONFIGURATION
# ------------------------

SEED = 42
NUM_GRAPHS = 100
NUM_NODES = 10
EDGE_PROB = 0.4

EMBEDDING_DIM = 500
config = read_config("config/config.yaml")

# NetLSD
NETLSD_SCALE_STEPS = config["netlsd"]["SCALE_STEPS"]
NETLSD_APPROX = config["netlsd"]["APPROX"]

# FEATHER
FEATHER_ORDER = config["feather"]["FEATHER_ORDER"]
FEATHER_EVAL_POINTS = config["feather"]["FEATHER_EVAL_POINTS"]
FEATHER_THETA_MAX = config["feather"]["FEATHER_THETA_MAX"]
FEATHER_POOLING = config["feather"]["FEATHER_POOLING"]

# GNN
NODE_FEATURE_DIM = config["gnn"]["NODE_FEATURE_DIM"]

# Perturbation
PERTURB_RATE = 0.1

np.random.seed(SEED)

# %%
# ------------------------
# UTILITY FUNCTIONS
# ------------------------

def perturb_graph(G, p=0.1):
    Gp = G.copy()
    nodes = list(Gp.nodes())

    for u, v in list(Gp.edges()):
        if np.random.rand() < p:
            Gp.remove_edge(u, v)

    for _ in range(int(p * len(nodes))):
        u, v = np.random.choice(nodes, 2, replace=False)
        Gp.add_edge(u, v)

    return Gp

# %%
# ------------------------
# GRAPH GENERATION
# ------------------------

graphs = []

for _ in range(NUM_GRAPHS):
    G = nx.erdos_renyi_graph(NUM_NODES, EDGE_PROB)

    for u, v in G.edges():
        G[u][v]["weight"] = np.random.uniform(0.5, 2.0)

    # node features (required by trained GNN)
    for n in G.nodes():
        G.nodes[n]["x"] = np.random.randn(NODE_FEATURE_DIM)

    graphs.append(G)

print(f"Generated {NUM_GRAPHS} graphs with {NUM_NODES} nodes each.")
# Out:
# Generated 100 graphs with 10 nodes each.

# %%
# ------------------------
# NetLSD EMBEDDINGS
# ------------------------

netlsd = NetLSD(
    scale_steps=NETLSD_SCALE_STEPS,
    approximations=NETLSD_APPROX,
    seed=SEED,
)

netlsd.fit(graphs)
netlsd_emb = netlsd.get_embedding()

print("NetLSD shape:", netlsd_emb.shape)
# Out:
# /home/mrzaizai2k/code_bao/ADAPT_GPT/src/embedding/embedding_utils.py:65: UserWarning: Please do be advised that the graph you have provided does not contain (some) edges in the main diagonal, for instance the self-loop constitued of (0, 0). These selfloops are necessary to ensure that the graph is traversable, and for this reason we create a copy of the graph and add therein the missing edges. Since we are creating a copy, this will immediately duplicate the memory requirements. To avoid this double allocation, you can provide the graph with the selfloops.
#   warnings.warn(
# NetLSD: 100%|██████████| 100/100 [00:00<00:00, 438.70it/s]
# NetLSD shape: (100, 500)

# %%
# ------------------------
# FEATHERG EMBEDDINGS
# ------------------------

feather = FEATHERG(
    theta_max=FEATHER_THETA_MAX,
    eval_points=FEATHER_EVAL_POINTS,
    order=FEATHER_ORDER,
    pooling=FEATHER_POOLING,
)

feather.fit(graphs)
feather_emb = feather.get_embedding()

print("FEATHER shape:", feather_emb.shape)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1683.35it/s]
# FEATHER shape: (100, 500)

# %%
# ------------------------
# GNN EMBEDDINGS
# ------------------------

gnn = GNN()

gnn_emb = gnn.get_embedding(graphs)

print("GNN shape:", gnn_emb.shape)
# Out:
# GNN model initialized on device: cuda
# GNN:   0%|          | 0/100 [00:00<?, ?it/s]/home/mrzaizai2k/anaconda3/envs/adapt_gpt/lib/python3.10/site-packages/torch_geometric/utils/convert.py:278: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   data_dict[key] = torch.as_tensor(value)
# GNN: 100%|██████████| 100/100 [00:00<00:00, 146.76it/s]
# GNN shape: (100, 500)
# GNN shape: (100, 500)

# %%
# ------------------------
# PAIRWISE DISTANCE HEATMAPS
# ------------------------

methods = {
    "NetLSD": netlsd_emb,
    "FEATHER": feather_emb,
    "GNN": gnn_emb,
}

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, (name, emb) in zip(axes, methods.items()):
    dist = squareform(pdist(emb, metric="cosine"))
    im = ax.imshow(dist)
    ax.set_title(name)
    plt.colorbar(im, ax=ax)

plt.suptitle("Cosine Distance Between Graph Embeddings")
plt.tight_layout()
plt.show()

# %%
# ------------------------
# PCA VISUALIZATION (2D)
# ------------------------

plt.figure(figsize=(6, 5))

for name, emb in methods.items():
    emb_2d = PCA(n_components=2).fit_transform(emb)
    plt.scatter(emb_2d[:, 0], emb_2d[:, 1], label=name, s=70)

plt.legend()
plt.title("PCA Projection of Graph Embeddings")
plt.grid(True)
plt.show()

# %%
# ------------------------
# EMBEDDING VARIANCE ANALYSIS
# ------------------------

for name, emb in methods.items():
    var = np.mean(np.std(emb, axis=0))
    print(f"{name} mean per-dimension std: {var:.6f}")
# Out:
# NetLSD mean per-dimension std: 0.004558
# FEATHER mean per-dimension std: 0.170165
# GNN mean per-dimension std: 0.097890

# %%
# ------------------------
# STABILITY UNDER PERTURBATION
# ------------------------

perturbed_graphs = [perturb_graph(G, PERTURB_RATE) for G in graphs]

# NetLSD
netlsd_p = NetLSD(
    scale_steps=NETLSD_SCALE_STEPS,
    approximations=NETLSD_APPROX,
    seed=SEED,
)
netlsd_p.fit(perturbed_graphs)
netlsd_shift = np.linalg.norm(
    netlsd_emb - netlsd_p.get_embedding(),
    axis=1,
)

# FEATHER
feather_p = FEATHERG(
    theta_max=FEATHER_THETA_MAX,
    eval_points=FEATHER_EVAL_POINTS,
    order=FEATHER_ORDER,
    pooling=FEATHER_POOLING,
)
feather_p.fit(perturbed_graphs)
feather_shift = np.linalg.norm(
    feather_emb - feather_p.get_embedding(),
    axis=1,
)

# GNN
gnn_shift = np.linalg.norm(
    gnn_emb - gnn.get_embedding(perturbed_graphs),
    axis=1,
)
# Out:
# /home/mrzaizai2k/code_bao/ADAPT_GPT/src/embedding/embedding_utils.py:65: UserWarning: Please do be advised that the graph you have provided does not contain (some) edges in the main diagonal, for instance the self-loop constitued of (0, 0). These selfloops are necessary to ensure that the graph is traversable, and for this reason we create a copy of the graph and add therein the missing edges. Since we are creating a copy, this will immediately duplicate the memory requirements. To avoid this double allocation, you can provide the graph with the selfloops.
#   warnings.warn(
# NetLSD: 100%|██████████| 100/100 [00:00<00:00, 459.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 1996.26it/s]
# GNN: 100%|██████████| 100/100 [00:00<00:00, 402.36it/s]
# GNN shape: (100, 500)

# %%
# ------------------------
# STABILITY PLOT
# ------------------------

plt.figure(figsize=(6, 4))
plt.plot(netlsd_shift, marker="o", label="NetLSD")
plt.plot(feather_shift, marker="^", label="FEATHER")
plt.plot(gnn_shift, marker="s", label="GNN")
plt.xlabel("Graph index")
plt.ylabel("Embedding shift (L2)")
plt.title("Stability Under Edge Perturbation")
plt.legend()
plt.grid(True)
plt.show()
